# %%
x = str(input("traffic signal"))
if x == "green":
  print("go")
elif x == "yello":
  print("ready to go")
else :
  print("stop")

# %%
x=int(input("enter the number "))
i=1
for i in range(i,x+1):
 print(i)

# %%
x=int(input("enter the number"))
i=1
for i in range(i,x+1,3):
  print(i)

# %%
x=int(input("enter your age"))
if x>=18:

  print("elligle for vote")
else:
  print("not elligle for vote")

# %%
x = int(input("positive or negative"))
if x <0:
  print("negative number")
else:
  print("positive number")

# %%
x=int(input("enter the number"))
if x<=9:
  print("single digit number")
elif x<100:
  print("double digit")
else:
  print("trible digit")

# %%
x=int(input("enter the number"))
if x % 3 == 0:
  print("divide by three")
else:
  print("not divide bby three")
# Out:
#   File "/tmp/ipykernel_5280/1939860616.py", line 2
#     if x%=3:
#         ^
# SyntaxError: invalid syntax

# %%
x=int(input("enter the number"))
if x % 3 ==0:
  print("divide by three")
else:
  print("not divide by three")
